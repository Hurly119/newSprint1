# %% [markdown]
# # Sprint 1 - Lab Exercise - 20210114
#
# **Team Pat Members:** Hurly | Joseph | Mikee | Phoemela
#
# -------------------
#
# ### Instructions
#
# **Setup**
# - Download the files from the compressed folder: [education_analytics.zip](https://courses.eskwelabs.com/courses/18/files/3662/download?wrap=1)
# - You will be doing the rest of the exercise from scratch.
#
# **Performing EDA**
# - Read and check all csv, is it possible to merge all csv into one?
# - Combine all mergeable csv into one dataframe.
# - Study the consolidated dataframe. What are you most interested in finding out?
# - Discuss among your group what are the conceptualization questions you want to answer.
# - Identify if this can be operationalized using the data provided.
# - Provide at least 3 questions for your group to answer.
# - Use what you've learned in the previous days to answer your questions.
#
# **Presenting Results**
# - Prepare one powerpoint or google slides presentation for your group
# - The presentation must contain:
#     (a) Background / Context: What problem or questions are you trying to solve?
#     (b) Data Information: What is your source of data? Which information from the data did you use? How reliable is the data?
#     (c) Methodology: What are the tools you used? What is your process flow to arrive at the solution?
#     (d) Results: What did you find out?
#     (e) Conclusion and Recommendations: Based on what you discovered, what can be done?
# - You will be given only 5 minutes to present your powerpoint. Ensure that your presentation is concise but informative.
#
#
# ---------------
#
# ### Tasks
#
# **7:35 to 8:00 PM** - All will check the different datasets provided and merge it into one usable dataframe that everyone in the team can use for the EDA. Remember to check shape, columns, and other info provided for each dataset. Also check for missing and duplicate values.
#
# **8:00 to 8:10 PM** - After knowing available information, what do you want to know from the data? Think of 4 questions to answer (1 question per fellow).
#
# **8:10 to 8:30 PM** - Each fellow will wrangle final dataframe to answer their own question and come up with a graph visualizing the result. Choose a visual that best represents your result.
#
# **8:30 PM to 8:55 PM** - Create presentation slides. Each fellow will work on at least 2 slides. One for the result of their EDA + another part of presentation (background, data information, methodology, conclusion & recommendations)

# %% [markdown]
# ----------------------
#
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# ----------------------
#
#
# ## Data Preparation

# %%
# Code for data checks + merging

import glob

masterlist = pd.read_csv('Masterlist of Schools.csv')
print(masterlist.shape)
print(masterlist.columns)

df_all = masterlist.copy()

files = glob.glob('*.csv')

for file in files:
    if 'Masterlist' not in file:
        try:
            file_df = pd.read_csv(file, encoding = 'utf-8')
        except:
            file_df = pd.read_csv(file, encoding = 'latin-1')
        print(file)
        print(file_df.shape)
        print(file_df.columns)
        if 'School ID' in file_df.columns:
            file_df = file_df.rename(columns = {'School ID':'school.id'})
        df_all = df_all.merge(file_df, on = 'school.id', how = 'left')
        
print(df_all.shape)
print(df_all.columns)
print(df_all.info())
# Out:
# (46603, 23)
# Index(['school.id', 'school.name', 'school.region', 'school.region.name',
#        'school.province', 'school.cityhall', 'school.division',
#        'school.citymuni', 'school.district', 'school.legdistrict',
#        'school.type', 'school.abbrev', 'school.previousname',
#        'school.mother.id', 'school.address', 'school.established',
#        'school.classification', 'school.classification2',
#        'school.curricularclass', 'school.organization', 'school.cityincome',
#        'school.cityclass', 'school.urban'],
#       dtype='object')
# Enrollment Master Data_2015_E.csv
# (38649, 17)
# Index(['School ID', 'Kinder Male', 'Kinder Female', 'Grade 1 Male',
#        'Grade 1 Female', 'Grade 2 Male', 'Grade 2 Female', 'Grade 3 Male',
#        'Grade 3 Female', 'Grade 4 Male', 'Grade 4 Female', 'Grade 5 Male',
#        'Grade 5 Female', 'Grade 6 Male', 'Grade 6 Female', 'SPED NG Male',
#        'SPED NG Female'],
#       dtype='object')
# Enrollment Master Data_2015_S.csv
# (7977, 15)
# Index(['School ID', 'Grade 7 Male', 'Grade 7 Female', 'Grade 8 Male',
#        'Grade 8 Female', 'Grade 9 Male', 'Grade 9 Female', 'Grade 10 Male',
#        'Grade 10 Female', 'Grade 11 Male', 'Grade 11 Female', 'Grade 12 Male',
#        'Grade 12 Female', 'SPED NG Male', 'SPED NG Female'],
#       dtype='object')
# MOOE data.csv
# (44028, 5)
# Index(['school.id', 'school.name', 'school.enrollment', 'school.offering',
#        ' school.mooe '],
#       dtype='object')
# Rooms data.csv
# (46412, 5)
# Index(['School ID', 'rooms.standard.academic', 'rooms.standard.unused',
#        'rooms.nonstandard.academic', 'rooms.nonstandard.unused'],
#       dtype='object')
# Schools Location Data.csv
# (46624, 12)
# Index(['School ID', 'School Name', 'Region', 'Province', 'Municipality',
#        'Division', 'District', 'Offering', 'Name of Principal', 'Enrolment',
#        'Latitude', 'Longitude'],
#       dtype='object')
# Teachers data.csv
# (45040, 5)
# Index(['school.id', 'teachers.instructor', 'teachers.mobile',
#        'teachers.regular', 'teachers.sped'],
#       dtype='object')
# (46603, 76)
# Index(['school.id', 'school.name_x', 'school.region', 'school.region.name',
#        'school.province', 'school.cityhall', 'school.division',
#        'school.citymuni', 'school.district', 'school.legdistrict',
#        'school.type', 'school.abbrev', 'school.previousname',
#        'school.mother.id', 'school.address', 'school.established',
#        'school.classification', 'school.classification2',
#        'school.curricularclass', 'school.organization', 'school.cityincome',
#        'school.cityclass', 'school.urban', 'Kinder Male', 'Kinder Female',
#        'Grade 1 Male', 'Grade 1 Female', 'Grade 2 Male', 'Grade 2 Female',
#        'Grade 3 Male', 'Grade 3 Female', 'Grade 4 Male', 'Grade 4 Female',
#        'Grade 5 Male', 'Grade 5 Female', 'Grade 6 Male', 'Grade 6 Female',
#        'SPED NG Male_x', 'SPED NG Female_x', 'Grade 7 Male', 'Grade 7 Female',
#        'Grade 8 Male', 'Grade 8 Female', 'Grade 9 Male', 'Grade 9 Female',
#        'Grade 10 Male', 'Grade 10 Female', 'Grade 11 Male', 'Grade 11 Female',
#        'Grade 12 Male', 'Grade 12 Female', 'SPED NG Male_y',
#        'SPED NG Female_y', 'school.name_y', 'school.enrollment',
#        'school.offering', ' school.mooe ', 'rooms.standard.academic',
#        'rooms.standard.unused', 'rooms.nonstandard.academic',
#        'rooms.nonstandard.unused', 'School Name', 'Region', 'Province',
#        'Municipality', 'Division', 'District', 'Offering', 'Name of Principal',
#        'Enrolment', 'Latitude', 'Longitude', 'teachers.instructor',
#        'teachers.mobile', 'teachers.regular', 'teachers.sped'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46603 entries, 0 to 46602
# Data columns (total 76 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   school.id                   46603 non-null  int64
#  1   school.name_x               46603 non-null  object
#  2   school.region               46603 non-null  object
#  3   school.region.name          46603 non-null  object
#  4   school.province             46603 non-null  object
#  5   school.cityhall             46602 non-null  object
#  6   school.division             46603 non-null  object
#  7   school.citymuni             46603 non-null  object
#  8   school.district             46603 non-null  object
#  9   school.legdistrict          46603 non-null  object
#  10  school.type                 46603 non-null  object
#  11  school.abbrev               18167 non-null  object
#  12  school.previousname         42221 non-null  object
#  13  school.mother.id            46596 non-null  float64
#  14  school.address              44621 non-null  object
#  15  school.established          46594 non-null  object
#  16  school.classification       46603 non-null  object
#  17  school.classification2      46603 non-null  object
#  18  school.curricularclass      46603 non-null  object
#  19  school.organization         46603 non-null  object
#  20  school.cityincome           45627 non-null  object
#  21  school.cityclass            8213 non-null   object
#  22  school.urban                46600 non-null  object
#  23  Kinder Male                 38618 non-null  float64
#  24  Kinder Female               38618 non-null  float64
#  25  Grade 1 Male                38618 non-null  float64
#  26  Grade 1 Female              38618 non-null  float64
#  27  Grade 2 Male                38618 non-null  float64
#  28  Grade 2 Female              38618 non-null  float64
#  29  Grade 3 Male                38618 non-null  float64
#  30  Grade 3 Female              38618 non-null  float64
#  31  Grade 4 Male                38618 non-null  float64
#  32  Grade 4 Female              38618 non-null  float64
#  33  Grade 5 Male                38618 non-null  float64
#  34  Grade 5 Female              38618 non-null  float64
#  35  Grade 6 Male                38618 non-null  float64
#  36  Grade 6 Female              38618 non-null  float64
#  37  SPED NG Male_x              38618 non-null  float64
#  38  SPED NG Female_x            38618 non-null  float64
#  39  Grade 7 Male                7911 non-null   object
#  40  Grade 7 Female              7911 non-null   object
#  41  Grade 8 Male                7911 non-null   object
#  42  Grade 8 Female              7911 non-null   object
#  43  Grade 9 Male                7911 non-null   object
#  44  Grade 9 Female              7911 non-null   object
#  45  Grade 10 Male               7911 non-null   object
#  46  Grade 10 Female             7911 non-null   object
#  47  Grade 11 Male               7911 non-null   float64
#  48  Grade 11 Female             7911 non-null   float64
#  49  Grade 12 Male               7911 non-null   float64
#  50  Grade 12 Female             7911 non-null   float64
#  51  SPED NG Male_y              7911 non-null   float64
#  52  SPED NG Female_y            7911 non-null   float64
#  53  school.name_y               44025 non-null  object
#  54  school.enrollment           44025 non-null  float64
#  55  school.offering             44025 non-null  object
#  56   school.mooe                44025 non-null  object
#  57  rooms.standard.academic     46357 non-null  float64
#  58  rooms.standard.unused       46357 non-null  float64
#  59  rooms.nonstandard.academic  46353 non-null  float64
#  60  rooms.nonstandard.unused    46353 non-null  float64
#  61  School Name                 46529 non-null  object
#  62  Region                      46529 non-null  object
#  63  Province                    46529 non-null  object
#  64  Municipality                46529 non-null  object
#  65  Division                    46529 non-null  object
#  66  District                    46529 non-null  object
#  67  Offering                    46529 non-null  object
#  68  Name of Principal           46518 non-null  object
#  69  Enrolment                   46529 non-null  float64
#  70  Latitude                    46529 non-null  float64
#  71  Longitude                   46529 non-null  float64
#  72  teachers.instructor         45040 non-null  float64
#  73  teachers.mobile             45040 non-null  float64
#  74  teachers.regular            45040 non-null  float64
#  75  teachers.sped               45040 non-null  float64
# dtypes: float64(35), int64(1), object(40)
# memory usage: 27.4+ MB
# None

# %%
df_all = df_all.drop(columns=['school.name_y','School Name', 'Region', 'Province',
       'Municipality', 'Division', 'District', 'Offering'])

df_all = pd.melt(df_all, id_vars = ['school.id', 'school.name_x', 'school.region', 'school.region.name',
       'school.province', 'school.cityhall', 'school.division',
       'school.citymuni', 'school.district', 'school.legdistrict',
       'school.type', 'school.abbrev', 'school.previousname',
       'school.mother.id', 'school.address', 'school.established',
       'school.classification', 'school.classification2',
       'school.curricularclass', 'school.organization', 'school.cityincome',
       'school.cityclass', 'school.urban', 'school.enrollment',
       'school.offering', ' school.mooe ', 'rooms.standard.academic',
       'rooms.standard.unused', 'rooms.nonstandard.academic',
       'rooms.nonstandard.unused', 'Name of Principal',
       'Enrolment', 'Latitude', 'Longitude', 'teachers.instructor',
       'teachers.mobile', 'teachers.regular', 'teachers.sped'])


df_all['gender'] = ['Male' if 'Male|Male_x|Male_y' in x else 'Female' for x in df_all['variable']]
df_all['year_level'] = df_all['variable'].str.replace('Male|Male_x|Male_y|Female|Female_x|Female_y','').apply(lambda x: x.strip())
df_all = df_all.rename(columns = {'value': 'enroll_yr_gen'})

# %%
df_all['year_level'].unique()
# Out:
# array(['Kinder', 'Grade 1', 'Grade 2', 'Grade 3', 'Grade 4', 'Grade 5',
#        'Grade 6', 'SPED NG _x', 'Grade 7', 'Grade 8', 'Grade 9',
#        'Grade 10', 'Grade 11', 'Grade 12', 'SPED NG _y'], dtype=object)

# %%
df_all.isna().sum()
# Out:
# school.id                           0
# school.name_x                       0
# school.region                       0
# school.region.name                  0
# school.province                     0
# school.cityhall                    30
# school.division                     0
# school.citymuni                     0
# school.district                     0
# school.legdistrict                  0
# school.type                         0
# school.abbrev                  853080
# school.previousname            131460
# school.mother.id                  210
# school.address                  59460
# school.established                270
# school.classification               0
# school.classification2              0
# school.curricularclass              0
# school.organization                 0
# school.cityincome               29280
# school.cityclass              1151700
# school.urban                       90
# school.enrollment               77340
# school.offering                 77340
#  school.mooe                    77340
# rooms.standard.academic          7380
# rooms.standard.unused            7380
# rooms.nonstandard.academic       7500
# rooms.nonstandard.unused         7500
# Name of Principal                2550
# Enrolment                        2220
# Latitude                         2220
# Longitude                        2220
# teachers.instructor             46890
# teachers.mobile                 46890
# teachers.regular                46890
# teachers.sped                   46890
# variable                            0
# enroll_yr_gen                  669448
# gender                              0
# year_level                          0
# dtype: int64

# %%
df_all = df_all[~df_all['enroll_yr_gen'].isna()]

df_all.isna().sum()
# Out:
# school.id                          0
# school.name_x                      0
# school.region                      0
# school.region.name                 0
# school.province                    0
# school.cityhall                   14
# school.division                    0
# school.citymuni                    0
# school.district                    0
# school.legdistrict                 0
# school.type                        0
# school.abbrev                 446392
# school.previousname            67970
# school.mother.id                 110
# school.address                 31232
# school.established               132
# school.classification              0
# school.classification2             0
# school.curricularclass             0
# school.organization                0
# school.cityincome              15226
# school.cityclass              601118
# school.urban                      46
# school.enrollment              39358
# school.offering                39358
#  school.mooe                   39358
# rooms.standard.academic         3566
# rooms.standard.unused           3566
# rooms.nonstandard.academic      3630
# rooms.nonstandard.unused        3630
# Name of Principal                174
# Enrolment                          0
# Latitude                           0
# Longitude                          0
# teachers.instructor            22632
# teachers.mobile                22632
# teachers.regular               22632
# teachers.sped                  22632
# variable                           0
# enroll_yr_gen                      0
# gender                             0
# year_level                         0
# dtype: int64

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 728642 entries, 0 to 1398089
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   school.id                   728642 non-null  int64
#  1   school.name_x               728642 non-null  object
#  2   school.region               728642 non-null  object
#  3   school.region.name          728642 non-null  object
#  4   school.province             728642 non-null  object
#  5   school.cityhall             728628 non-null  object
#  6   school.division             728642 non-null  object
#  7   school.citymuni             728642 non-null  object
#  8   school.district             728642 non-null  object
#  9   school.legdistrict          728642 non-null  object
#  10  school.type                 728642 non-null  object
#  11  school.abbrev               282250 non-null  object
#  12  school.previousname         660672 non-null  object
#  13  school.mother.id            728532 non-null  float64
#  14  school.address              697410 non-null  object
#  15  school.established          728510 non-null  object
#  16  school.classification       728642 non-null  object
#  17  school.classification2      728642 non-null  object
#  18  school.curricularclass      728642 non-null  object
#  19  school.organization         728642 non-null  object
#  20  school.cityincome           713416 non-null  object
#  21  school.cityclass            127524 non-null  object
#  22  school.urban                728596 non-null  object
#  23  school.enrollment           689284 non-null  float64
#  24  school.offering             689284 non-null  object
#  25   school.mooe                689284 non-null  object
#  26  rooms.standard.academic     725076 non-null  float64
#  27  rooms.standard.unused       725076 non-null  float64
#  28  rooms.nonstandard.academic  725012 non-null  float64
#  29  rooms.nonstandard.unused    725012 non-null  float64
#  30  Name of Principal           728468 non-null  object
#  31  Enrolment                   728642 non-null  float64
#  32  Latitude                    728642 non-null  float64
#  33  Longitude                   728642 non-null  float64
#  34  teachers.instructor         706010 non-null  float64
#  35  teachers.mobile             706010 non-null  float64
#  36  teachers.regular            706010 non-null  float64
#  37  teachers.sped               706010 non-null  float64
#  38  variable                    728642 non-null  object
#  39  enroll_yr_gen               728642 non-null  object
#  40  gender                      728642 non-null  object
#  41  year_level                  728642 non-null  object
# dtypes: float64(13), int64(1), object(28)
# memory usage: 239.0+ MB

# %% [markdown]
# ----------------------
#
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### Question 1
#
# Difference between MOOE of primary and secondary education by province

# %%
# Codes for question 1
# Out:
# 0             341,000.00
# 1             275,000.00
# 2             132,000.00
# 3             135,000.00
# 4             182,000.00
#                 ...
# 1398085       986,000.00
# 1398086     1,798,000.00
# 1398087     3,971,000.00
# 1398088       539,000.00
# 1398089     3,595,000.00
# Name:  school.mooe , Length: 728642, dtype: object

# %%
df_all2 = df_all[~df_all[" school.mooe "].isna()]
df_all2
# Out:
#          school.id                             school.name_x school.region  \
# 0           101746                           A. Diaz, Sr. ES      Region I
# 1           102193             A. P. Santos ES (SPED Center)      Region I
# 2           101283                           A.P. Guevara IS      Region I
# 3           100216                                Ab-Abut ES      Region I
# 4           100043                                  Abaca ES      Region I
# ...            ...                                       ...           ...
# 1398085     305308  Valeriano E. Fugoso Memorial High School           NCR
# 1398086     320402       Vicente Trinidad NHS (Punturin NHS)           NCR
# 1398087     305315               Victoriano Mapa High School           NCR
# 1398088     320407           Wawangpulo National High School           NCR
# 1398089     305465                       Western Bicutan NHS           NCR
#
#               school.region.name              school.province  \
# 0                  Ilocos Region                   PANGASINAN
# 1                  Ilocos Region                 ILOCOS NORTE
# 2                  Ilocos Region                   PANGASINAN
# 3                  Ilocos Region                 ILOCOS NORTE
# 4                  Ilocos Region                 ILOCOS NORTE
# ...                          ...                          ...
# 1398085  National Capital Region  MANILA, NCR, FIRST DISTRICT
# 1398086  National Capital Region           NCR THIRD DISTRICT
# 1398087  National Capital Region  MANILA, NCR, FIRST DISTRICT
# 1398088  National Capital Region           NCR THIRD DISTRICT
# 1398089  National Capital Region          NCR FOURTH DISTRICT
#
#                      school.cityhall           school.division  \
# 0                         PANGASINAN  Pangasinan II, Binalonan
# 1                       ILOCOS NORTE                Laoag City
# 2                         PANGASINAN    Pangasinan I, Lingayen
# 3                       ILOCOS NORTE              Ilocos Norte
# 4                       ILOCOS NORTE              Ilocos Norte
# ...                              ...                       ...
# 1398085  MANILA, NCR, FIRST DISTRICT                    Manila
# 1398086           CITY OF VALENZUELA           Valenzuela City
# 1398087  MANILA, NCR, FIRST DISTRICT                    Manila
# 1398088           CITY OF VALENZUELA           Valenzuela City
# 1398089                  TAGUIG CITY                    Taguig
#
#               school.citymuni                   school.district  \
# 0                    BAUTISTA                          Bautista
# 1        LAOAG CITY (Capital)            Laoag City District II
# 2                   BAYAMBANG                      Bayambang II
# 3                      PIDDIG                            Piddig
# 4                      BANGUI                            Bangui
# ...                       ...                               ...
# 1398085              SAMPALOC                        Sampaloc V
# 1398086    CITY OF VALENZUELA  Valenzuela City Central District
# 1398087            SAN MIGUEL                       Sta. Cruz V
# 1398088    CITY OF VALENZUELA    Valenzuela City North District
# 1398089           TAGUIG CITY               Taguig District III
#
#         school.legdistrict  ...   Latitude   Longitude teachers.instructor  \
# 0             5th District  ...  15.799122  120.498531                 0.0
# 1             1st District  ...  18.196389  120.586667                 0.0
# 2             3rd District  ...  15.780155  120.460509                 0.0
# 3             1st District  ...  18.168875  120.695392                 0.0
# 4             1st District  ...  18.531941  120.755890                 0.0
# ...                    ...  ...        ...         ...                 ...
# 1398085       4th District  ...  14.611200  120.993006                 0.0
# 1398086       1st District  ...  14.735556  120.990833                 0.0
# 1398087       6th District  ...  14.597933  120.992278                 0.0
# 1398088       1st District  ...  14.732781  120.928336                 0.0
# 1398089       2nd District  ...  14.516651  121.050701                 0.0
#
#          teachers.mobile teachers.regular teachers.sped          variable  \
# 0                    1.0             20.0           0.0       Kinder Male
# 1                    2.0             12.0           4.0       Kinder Male
# 2                    1.0              6.0           0.0       Kinder Male
# 3                    1.0              6.0           0.0       Kinder Male
# 4                    1.0              8.0           0.0       Kinder Male
# ...                  ...              ...           ...               ...
# 1398085              7.0             39.0           0.0  SPED NG Female_y
# 1398086              4.0             41.0           0.0  SPED NG Female_y
# 1398087             27.0            164.0           0.0  SPED NG Female_y
# 1398088              0.0              6.0           0.0  SPED NG Female_y
# 1398089              1.0             96.0           0.0  SPED NG Female_y
#
#         enroll_yr_gen  gender  year_level
# 0                  57  Female      Kinder
# 1                  20  Female      Kinder
# 2                  16  Female      Kinder
# 3                  10  Female      Kinder
# 4                  12  Female      Kinder
# ...               ...     ...         ...
# 1398085             0  Female  SPED NG _y
# 1398086             0  Female  SPED NG _y
# 1398087             0  Female  SPED NG _y
# 1398088             0  Female  SPED NG _y
# 1398089             0  Female  SPED NG _y
#
# [689284 rows x 42 columns]

# %%
primary = df_all2[df_all2["year_level"].isin(['Grade 1', 'Grade 2', 'Grade 3', 'Grade 4', 'Grade 5',
       'Grade 6'])]
primary[" school.mooe "]= primary[" school.mooe "].str.replace(",","").astype(float)
# Out:
# <ipython-input-84-3f10df08c180>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary[" school.mooe "]= primary[" school.mooe "].str.replace(",","").astype(float)

# %%
second = df_all2[df_all2["year_level"].isin(['Grade 7', 'Grade 8', 'Grade 9',
       'Grade 10', 'Grade 11', 'Grade 12'])]
second[" school.mooe "]= second[" school.mooe "].str.replace(",","").astype(float)
# Out:
# <ipython-input-59-004f95bdc693>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second[" school.mooe "]= second[" school.mooe "].str.replace(",","").astype(float)

# %%
second2 = second.groupby(["school.province","school.id"])[" school.mooe "].mean().reset_index()

# %%
second3 = second2.groupby("school.province")[" school.mooe "].mean().reset_index()

# %%
primary2 = primary.groupby(["school.province","school.id"])[" school.mooe "].mean().reset_index()
primary3 = primary2.groupby("school.province")[" school.mooe "].mean().reset_index()

# %%
plt.figure(figsize=(15, 12))
sns.barplot(x=" school.mooe ", y="school.province", data=second3.sort_values(by=" school.mooe ",ascending=False).head(10))
plt.savefig('secondaryBar.png')
plt.show()

# %%
plt.figure(figsize=(15, 12))
sns.barplot(x=" school.mooe ", y="school.province", data=primary3.sort_values(by=" school.mooe ",ascending=False).head(10))
plt.savefig('primaryBar.png')
plt.show()

# %%
second2
# Out:
#         school.province  school.id   school.mooe
# 0                  ABRA     305074       223000.0
# 1                  ABRA     305075      2182000.0
# 2                  ABRA     305076       279000.0
# 3                  ABRA     305077       186000.0
# 4                  ABRA     305078       240000.0
# ...                 ...        ...            ...
# 7553  ZAMBOANGA SIBUGAY     314321       235000.0
# 7554  ZAMBOANGA SIBUGAY     314322       237000.0
# 7555  ZAMBOANGA SIBUGAY     314323       186000.0
# 7556  ZAMBOANGA SIBUGAY     314324       233000.0
# 7557  ZAMBOANGA SIBUGAY     314325       220000.0
#
# [7558 rows x 3 columns]

# %%
shapefile = gpd.read_file("./PH Provinces Shapefile/Provinces.shp")
shapefile["PROVINCE"] = shapefile["PROVINCE"].str.upper()
shapefile
# Out:
#     ID_0  ISO       NAME_0  ID_1               NAME_1 NL_NAME_1 VARNAME_1  \
# 0    177  PHL  Philippines     1                 Abra      None      None
# 1    177  PHL  Philippines     2     Agusan del Norte      None      None
# 2    177  PHL  Philippines     3       Agusan del Sur      None      None
# 3    177  PHL  Philippines     4                Aklan      None      None
# 4    177  PHL  Philippines     5                Albay      None      None
# ..   ...  ...          ...   ...                  ...       ...       ...
# 77   177  PHL  Philippines    78            Tawi-Tawi      None      None
# 78   177  PHL  Philippines    79             Zambales      None      None
# 79   177  PHL  Philippines    80  Zamboanga del Norte      None      None
# 80   177  PHL  Philippines    81    Zamboanga del Sur      None      None
# 81   177  PHL  Philippines    82    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1             PROVINCE  \
# 0   Lalawigan|Probinsya  Province                 ABRA
# 1   Lalawigan|Probinsya  Province     AGUSAN DEL NORTE
# 2   Lalawigan|Probinsya  Province       AGUSAN DEL SUR
# 3   Lalawigan|Probinsya  Province                AKLAN
# 4   Lalawigan|Probinsya  Province                ALBAY
# ..                  ...       ...                  ...
# 77  Lalawigan|Probinsya  Province            TAWI-TAWI
# 78  Lalawigan|Probinsya  Province             ZAMBALES
# 79  Lalawigan|Probinsya  Province  ZAMBOANGA DEL NORTE
# 80  Lalawigan|Probinsya  Province    ZAMBOANGA DEL SUR
# 81  Lalawigan|Probinsya  Province    ZAMBOANGA SIBUGAY
#
#                                          REGION  \
# 0        Cordillera Administrative Region (CAR)
# 1                          Caraga (Region XIII)
# 2                          Caraga (Region XIII)
# 3                   Western Visayas (Region VI)
# 4                       Bicol Region (Region V)
# ..                                          ...
# 77  Autonomous Region of Muslim Mindanao (ARMM)
# 78                   Central Luzon (Region III)
# 79              Zamboanga Peninsula (Region IX)
# 80              Zamboanga Peninsula (Region IX)
# 81              Zamboanga Peninsula (Region IX)
#
#                                              geometry
# 0   POLYGON ((120.96795 17.95706, 120.97803 17.949...
# 1   POLYGON ((125.57724 9.45679, 125.59687 9.45509...
# 2   POLYGON ((125.91087 8.85625, 125.91461 8.85211...
# 3   MULTIPOLYGON (((122.43667 11.59833, 122.43667 ...
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# ..                                                ...
# 77  MULTIPOLYGON (((119.46694 4.58694, 119.46639 4...
# 78  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...
# 79  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...
# 80  MULTIPOLYGON (((122.06223 6.87278, 122.06250 6...
# 81  MULTIPOLYGON (((122.84063 7.27694, 122.84048 7...
#
# [82 rows x 12 columns]

# %%
primaryMap = pd.merge(shapefile,primary3,left_on="PROVINCE",right_on="school.province")
primaryMap
# Out:
#     ID_0  ISO       NAME_0  ID_1               NAME_1 NL_NAME_1 VARNAME_1  \
# 0    177  PHL  Philippines     1                 Abra      None      None
# 1    177  PHL  Philippines     2     Agusan del Norte      None      None
# 2    177  PHL  Philippines     3       Agusan del Sur      None      None
# 3    177  PHL  Philippines     4                Aklan      None      None
# 4    177  PHL  Philippines     5                Albay      None      None
# ..   ...  ...          ...   ...                  ...       ...       ...
# 69   177  PHL  Philippines    77               Tarlac      None      None
# 70   177  PHL  Philippines    79             Zambales      None      None
# 71   177  PHL  Philippines    80  Zamboanga del Norte      None      None
# 72   177  PHL  Philippines    81    Zamboanga del Sur      None      None
# 73   177  PHL  Philippines    82    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1             PROVINCE  \
# 0   Lalawigan|Probinsya  Province                 ABRA
# 1   Lalawigan|Probinsya  Province     AGUSAN DEL NORTE
# 2   Lalawigan|Probinsya  Province       AGUSAN DEL SUR
# 3   Lalawigan|Probinsya  Province                AKLAN
# 4   Lalawigan|Probinsya  Province                ALBAY
# ..                  ...       ...                  ...
# 69  Lalawigan|Probinsya  Province               TARLAC
# 70  Lalawigan|Probinsya  Province             ZAMBALES
# 71  Lalawigan|Probinsya  Province  ZAMBOANGA DEL NORTE
# 72  Lalawigan|Probinsya  Province    ZAMBOANGA DEL SUR
# 73  Lalawigan|Probinsya  Province    ZAMBOANGA SIBUGAY
#
#                                     REGION  \
# 0   Cordillera Administrative Region (CAR)
# 1                     Caraga (Region XIII)
# 2                     Caraga (Region XIII)
# 3              Western Visayas (Region VI)
# 4                  Bicol Region (Region V)
# ..                                     ...
# 69              Central Luzon (Region III)
# 70              Central Luzon (Region III)
# 71         Zamboanga Peninsula (Region IX)
# 72         Zamboanga Peninsula (Region IX)
# 73         Zamboanga Peninsula (Region IX)
#
#                                              geometry      school.province  \
# 0   POLYGON ((120.96795 17.95706, 120.97803 17.949...                 ABRA
# 1   POLYGON ((125.57724 9.45679, 125.59687 9.45509...     AGUSAN DEL NORTE
# 2   POLYGON ((125.91087 8.85625, 125.91461 8.85211...       AGUSAN DEL SUR
# 3   MULTIPOLYGON (((122.43667 11.59833, 122.43667 ...                AKLAN
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...                ALBAY
# ..                                                ...                  ...
# 69  POLYGON ((120.63007 15.73335, 120.63052 15.729...               TARLAC
# 70  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...             ZAMBALES
# 71  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...  ZAMBOANGA DEL NORTE
# 72  MULTIPOLYGON (((122.06223 6.87278, 122.06250 6...    ZAMBOANGA DEL SUR
# 73  MULTIPOLYGON (((122.84063 7.27694, 122.84048 7...    ZAMBOANGA SIBUGAY
#
#      school.mooe
# 0   112364.620939
# 1   210494.880546
# 2   162413.186813
# 3   164675.000000
# 4   209857.142857
# ..            ...
# 69  207968.810916
# 70  233785.454545
# 71  165076.071923
# 72  193415.094340
# 73  159860.520095
#
# [74 rows x 14 columns]

# %%
secondaryMap = pd.merge(shapefile,second3,left_on="PROVINCE",right_on="school.province")
secondaryMap
# Out:
#     ID_0  ISO       NAME_0  ID_1               NAME_1 NL_NAME_1 VARNAME_1  \
# 0    177  PHL  Philippines     1                 Abra      None      None
# 1    177  PHL  Philippines     2     Agusan del Norte      None      None
# 2    177  PHL  Philippines     3       Agusan del Sur      None      None
# 3    177  PHL  Philippines     4                Aklan      None      None
# 4    177  PHL  Philippines     5                Albay      None      None
# ..   ...  ...          ...   ...                  ...       ...       ...
# 69   177  PHL  Philippines    77               Tarlac      None      None
# 70   177  PHL  Philippines    79             Zambales      None      None
# 71   177  PHL  Philippines    80  Zamboanga del Norte      None      None
# 72   177  PHL  Philippines    81    Zamboanga del Sur      None      None
# 73   177  PHL  Philippines    82    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1             PROVINCE  \
# 0   Lalawigan|Probinsya  Province                 ABRA
# 1   Lalawigan|Probinsya  Province     AGUSAN DEL NORTE
# 2   Lalawigan|Probinsya  Province       AGUSAN DEL SUR
# 3   Lalawigan|Probinsya  Province                AKLAN
# 4   Lalawigan|Probinsya  Province                ALBAY
# ..                  ...       ...                  ...
# 69  Lalawigan|Probinsya  Province               TARLAC
# 70  Lalawigan|Probinsya  Province             ZAMBALES
# 71  Lalawigan|Probinsya  Province  ZAMBOANGA DEL NORTE
# 72  Lalawigan|Probinsya  Province    ZAMBOANGA DEL SUR
# 73  Lalawigan|Probinsya  Province    ZAMBOANGA SIBUGAY
#
#                                     REGION  \
# 0   Cordillera Administrative Region (CAR)
# 1                     Caraga (Region XIII)
# 2                     Caraga (Region XIII)
# 3              Western Visayas (Region VI)
# 4                  Bicol Region (Region V)
# ..                                     ...
# 69              Central Luzon (Region III)
# 70              Central Luzon (Region III)
# 71         Zamboanga Peninsula (Region IX)
# 72         Zamboanga Peninsula (Region IX)
# 73         Zamboanga Peninsula (Region IX)
#
#                                              geometry      school.province  \
# 0   POLYGON ((120.96795 17.95706, 120.97803 17.949...                 ABRA
# 1   POLYGON ((125.57724 9.45679, 125.59687 9.45509...     AGUSAN DEL NORTE
# 2   POLYGON ((125.91087 8.85625, 125.91461 8.85211...       AGUSAN DEL SUR
# 3   MULTIPOLYGON (((122.43667 11.59833, 122.43667 ...                AKLAN
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...                ALBAY
# ..                                                ...                  ...
# 69  POLYGON ((120.63007 15.73335, 120.63052 15.729...               TARLAC
# 70  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...             ZAMBALES
# 71  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...  ZAMBOANGA DEL NORTE
# 72  MULTIPOLYGON (((122.06223 6.87278, 122.06250 6...    ZAMBOANGA DEL SUR
# 73  MULTIPOLYGON (((122.84063 7.27694, 122.84048 7...    ZAMBOANGA SIBUGAY
#
#      school.mooe
# 0    4.241515e+05
# 1    5.527294e+05
# 2    5.104375e+05
# 3    5.166125e+05
# 4    7.787131e+05
# ..            ...
# 69   1.000049e+06
# 70   7.296184e+05
# 71   5.522222e+05
# 72   6.612360e+05
# 73   5.284868e+05
#
# [74 rows x 14 columns]

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = ' school.mooe '
# set the range for the choropleth
vmin, vmax,vmin2,vmax2 = secondaryMap[variable].min(), secondaryMap[variable].max(),primaryMap[variable].min(), primaryMap[variable].max()
# create figure and axes for Matplotlib

fig, axes = plt.subplots(nrows=2, figsize=(20, 20))
fig.suptitle("Average Difference Between MOOE of Primary and Secondary Education by Province",fontsize=16)
# Complete the code

secondaryMap.plot(column=variable, cmap='Greys', linewidth=0.8, ax=axes[1], edgecolor='0.8', vmin=vmin, vmax=vmax)
axes[1].set_title("MOOE of Secondary Education by Province",fontsize=12)

primaryMap.plot(column=variable, cmap='Greys', linewidth=0.8, ax=axes[0], edgecolor='0.8', vmin=vmin2, vmax=vmax2)
axes[0].set_title("MOOE of Primary Education by Province",fontsize=12)
sm = plt.cm.ScalarMappable(cmap='Greys', norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)
for ax in axes:
    ax.set_anchor('W')

plt.savefig('graph.png')
plt.show()

# %% [markdown]
# ### Question 2
#
# <*Type question 2 here.*>

# %%
# Codes for question 2

# %% [markdown]
# ### Question 3
#
# <*Type question 3 here.*>

# %%
# Codes for question 3

# %% [markdown]
# ### Question 4
#
# <*Type question 4 here*>

# %%
# Codes for question 4
