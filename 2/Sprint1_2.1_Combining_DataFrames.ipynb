# %% [markdown]
# # Combining DataFrames

# %% [markdown]
# In this notebook, we will be working with multiple data sources.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### A. Concatenation
#
# Concatenation is simply appending one dataframe to another, either via rows or via columns. Think copy-pasting in Excel.

# %%
df1 = pd.DataFrame(np.arange(9).reshape((3, 3)), 
                   columns=['a', 'b', 'c'],
                   index=['one', 'two', 'three'])
df2 = pd.DataFrame(np.arange(6).reshape((3, 2)), 
                   columns=['d','e'],
                   index=['three', 'two','one'])
display(df1)
display(df2)
# Out:
#        a  b  c
# one    0  1  2
# two    3  4  5
# three  6  7  8
#        d  e
# three  0  1
# two    2  3
# one    4  5

# %% [markdown]
# - Since the two data frames have the same number of rows, it is natural to combine them "horizontally".
# - Note the concatenation takes place on the name of the index and not the order.

# %%
pd.concat([df1, df2], axis = 1, sort=False)
# Out:
#        a  b  c  d  e
# one    0  1  2  4  5
# two    3  4  5  2  3
# three  6  7  8  0  1

# %% [markdown]
# - The argument "axis = 1" means expanding along the column indices. Setting "axis = 0" will combine two data frames with same number of columns vertically.

# %%
pd.concat([df1, df2], axis = 0, sort=False)
# Out:
#          a    b    c    d    e
# one    0.0  1.0  2.0  NaN  NaN
# two    3.0  4.0  5.0  NaN  NaN
# three  6.0  7.0  8.0  NaN  NaN
# three  NaN  NaN  NaN  0.0  1.0
# two    NaN  NaN  NaN  2.0  3.0
# one    NaN  NaN  NaN  4.0  5.0

# %% [markdown]
# ### Try it!

# %% [markdown]
# We have here data from primary and secondary schools. We want to combine these data into one dataframe. Since the headers for both dataframes are the same, we can use concat.

# %%
# Reading dataframe1
primary = pd.read_csv("depend_publicelementary2015.csv", encoding="latin-1")
primary.head()
# Out:
#                      region      province municipality      division  \
# 0  Region I - Ilocos Region  Ilocos Norte      Bacarra  Ilocos Norte
# 1  Region I - Ilocos Region  Ilocos Norte      Bacarra  Ilocos Norte
# 2  Region I - Ilocos Region  Ilocos Norte      Bacarra  Ilocos Norte
# 3  Region I - Ilocos Region  Ilocos Norte      Bacarra  Ilocos Norte
# 4  Region I - Ilocos Region  Ilocos Norte      Bacarra  Ilocos Norte
#
#    school_id                school_name year_level gender  enrollment  \
# 0     100001         Apaleng-libtong ES    grade 1   male           9
# 1     100002                Bacarra CES    grade 1   male          41
# 2     100003                   Buyon ES    grade 1   male           7
# 3     100004  Ganagan Elementary School    grade 1   male           8
# 4     100005                 Macupit ES    grade 1   male           5
#
#       latitude    longitude
# 0    18.253666    120.60618
# 1  18.25096389  120.6089583
# 2    18.234599   120.616037
# 3  18.25001389  120.5871694
# 4  18.29399444  120.6410194

# %%
# Reading dataframe
secondary = pd.read_csv("deped_publicsecondary2015.csv", encoding="latin-1")
secondary.head()
# Out:
#    school_id                 school_name                    region  \
# 0     300001  Adams National High School  Region I - Ilocos Region
# 1     300002                Bacarra NCHS  Region I - Ilocos Region
# 2     300003                  Bangui NHS  Region I - Ilocos Region
# 3     300004  Banna National High School  Region I - Ilocos Region
# 4     300005  Batac National High School  Region I - Ilocos Region
#
#        province      municipality      division  year_level gender  \
# 0  Ilocos Norte             Adams  Ilocos Norte  first year   male
# 1  Ilocos Norte           Bacarra  Ilocos Norte  first year   male
# 2  Ilocos Norte            Bangui  Ilocos Norte  first year   male
# 3  Ilocos Norte  Banna (Espiritu)  Ilocos Norte  first year   male
# 4  Ilocos Norte     City Of Batac    Batac City  first year   male
#
#    enrollment     latitude    longitude
# 0          24     18.45859  120.9057909
# 1         299  18.24977222    120.61305
# 2          89   18.5356735   120.769735
# 3          50  17.98035278  120.6581583
# 4          66     18.11075  120.5718778

# %%
# Combine primary and secondary schools

#df_all_schools = 
df_all_schools = pd.concat([secondary,primary], sort=False)

df_all_schools
# Out:
#         school_id                                      school_name  \
# 0          300001                       Adams National High School
# 1          300002                                     Bacarra NCHS
# 2          300003                                       Bangui NHS
# 3          300004                       Banna National High School
# 4          300005                       Batac National High School
# 5          300006                    Burgos Agro-Industrial School
# 6          300007                   Cadaratan National High School
# 7          300008                                  Caestebanan NHS
# 8          300009                                       Carasi NHS
# 9          300010                                    Caribquib NHS
# 10         300011                                  Catagtaguen NHS
# 11         300012                       Crispina Marcos Valdez NHS
# 12         300013                                     Currimao NHS
# 13         300014                      Davila National High School
# 14         300015               Dingras NHS/Lt. Edgar Foz Mem. NHS
# 15         300016                      Piddig National High School
# 16         300017                                     Dumalneg NHS
# 17         300018                Ilocos Norte Agricultural College
# 18         300019                                       Luzong NHS
# 19         300020                                       Marcos NHS
# 20         300021                                    Nagrebcan NHS
# 21         300022                   NUEVA ERA NATIONAL HIGH SCHOOL
# 22         300023                                   Pagsanahan NHS
# 23         300024                                     Pagudpud NHS
# 24         300025                                   Paoay Lake NHS
# 25         300026                    Pasaleng National High School
# 26         300027                                       Pinili NHS
# 27         300028                                  San Nicolas NHS
# 28         300029                      Sarrat National High School
# 29         300030  Solsona National High School, Maananteng Campus
# ...           ...                                              ...
# 396258     133524                         Pagalongan Community CES
# 396259     133525                                   Pilintangan PS
# 396260     133526                         Wao Central Comm. School
# 396261     133527                             Western Wao Pilot ES
# 396262     133528                                       Balatin PS
# 396263     133529                                     Buntongan ES
# 396264     133530                                     Kilikili CES
# 396265     133531                                      Mimbuaya PS
# 396266     133532                               North Park Area ES
# 396267     133533                                       Pagayon ES
# 396268     133534                                        Panang ES
# 396269     133535                            Pulacan (Campo Ii) ES
# 396270     133536                                        Serran ES
# 396271     133537                               South Park Area ES
# 396272     133539                                        Comara ES
# 396273     133540                                    Francfort CES
# 396274     133541                                   Natangcopan PS
# 396275     133542                                         Punud ES
# 396276     133543                                         Salam PS
# 396277     133544                                       Sumugot ES
# 396278     133545                                         Barua ES
# 396279     133546                                   Cabombongan ES
# 396280     133547                             Gasan Primary School
# 396281     133549                                       Kalawi CES
# 396282     133552                                         Talob PS
# 396283     133553                                         Tambo PS
# 396284     133554                                          Tuka PS
# 396285     133555                                        Tulain PS
# 396286     133556                                        Ulodan ES
# 396287     133557                          Awani Elementary School
#
#                                              region       province  \
# 0                          Region I - Ilocos Region   Ilocos Norte
# 1                          Region I - Ilocos Region   Ilocos Norte
# 2                          Region I - Ilocos Region   Ilocos Norte
# 3                          Region I - Ilocos Region   Ilocos Norte
# 4                          Region I - Ilocos Region   Ilocos Norte
# 5                          Region I - Ilocos Region   Ilocos Norte
# 6                          Region I - Ilocos Region   Ilocos Norte
# 7                          Region I - Ilocos Region   Ilocos Norte
# 8                          Region I - Ilocos Region   Ilocos Norte
# 9                          Region I - Ilocos Region   Ilocos Norte
# 10                         Region I - Ilocos Region   Ilocos Norte
# 11                         Region I - Ilocos Region   Ilocos Norte
# 12                         Region I - Ilocos Region   Ilocos Norte
# 13                         Region I - Ilocos Region   Ilocos Norte
# 14                         Region I - Ilocos Region   Ilocos Norte
# 15                         Region I - Ilocos Region   Ilocos Norte
# 16                         Region I - Ilocos Region   Ilocos Norte
# 17                         Region I - Ilocos Region   Ilocos Norte
# 18                         Region I - Ilocos Region   Ilocos Norte
# 19                         Region I - Ilocos Region   Ilocos Norte
# 20                         Region I - Ilocos Region   Ilocos Norte
# 21                         Region I - Ilocos Region   Ilocos Norte
# 22                         Region I - Ilocos Region   Ilocos Norte
# 23                         Region I - Ilocos Region   Ilocos Norte
# 24                         Region I - Ilocos Region   Ilocos Norte
# 25                         Region I - Ilocos Region   Ilocos Norte
# 26                         Region I - Ilocos Region   Ilocos Norte
# 27                         Region I - Ilocos Region   Ilocos Norte
# 28                         Region I - Ilocos Region   Ilocos Norte
# 29                         Region I - Ilocos Region   Ilocos Norte
# ...                                             ...            ...
# 396258  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396259  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396260  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396261  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396262  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396263  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396264  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396265  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396266  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396267  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396268  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396269  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396270  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396271  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396272  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396273  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396274  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396275  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396276  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396277  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396278  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396279  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396280  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396281  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396282  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396283  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396284  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396285  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396286  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 396287  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
#
#                            municipality            division  year_level  \
# 0                                 Adams        Ilocos Norte  first year
# 1                               Bacarra        Ilocos Norte  first year
# 2                                Bangui        Ilocos Norte  first year
# 3                      Banna (Espiritu)        Ilocos Norte  first year
# 4                         City Of Batac          Batac City  first year
# 5                                Burgos        Ilocos Norte  first year
# 6                               Bacarra        Ilocos Norte  first year
# 7                      Banna (Espiritu)        Ilocos Norte  first year
# 8                                Carasi        Ilocos Norte  first year
# 9                      Banna (Espiritu)        Ilocos Norte  first year
# 10                     Banna (Espiritu)        Ilocos Norte  first year
# 11                        City Of Batac          Batac City  first year
# 12                             Currimao        Ilocos Norte  first year
# 13                             Pasuquin        Ilocos Norte  first year
# 14                              Dingras        Ilocos Norte  first year
# 15                               Piddig        Ilocos Norte  first year
# 16                             Dumalneg        Ilocos Norte  first year
# 17                             Pasuquin        Ilocos Norte  first year
# 18                             Pagudpud        Ilocos Norte  first year
# 19                               Marcos        Ilocos Norte  first year
# 20                                Badoc        Ilocos Norte  first year
# 21                            Nueva Era        Ilocos Norte  first year
# 22                                Badoc        Ilocos Norte  first year
# 23                             Pagudpud        Ilocos Norte  first year
# 24                                Paoay        Ilocos Norte  first year
# 25                             Pagudpud        Ilocos Norte  first year
# 26                               Pinili        Ilocos Norte  first year
# 27                          San Nicolas        Ilocos Norte  first year
# 28                               Sarrat        Ilocos Norte  first year
# 29                              Solsona        Ilocos Norte  first year
# ...                                 ...                 ...         ...
# 396258                              Wao   Lanao del Sur - I     grade 6
# 396258  female          37     7.683445   124.683614
# 396259  female           0            -            -
# 396260  female          66     7.641438   124.723656
# 396261  female         136     7.683328    124.68396
# 396262  female           0            -            -
# 396263  female          15            -            -
# 396264  female          48     7.742867   124.724007
# 396265  female           0            -            -
# 396266  female           5     7.689833   124.725388
# 396267  female           0            -            -
# 396268  female          16            -            -
# 396269  female           9            -            -
# 396270  female          13            -            -
# 396271  female          10            -            -
# 396272  female          31            -            -
# 396273  female          86  7.745416667  124.6635278
# 396274  female           0            -            -
# 396275  female          25       7.7455     124.6635
# 396276  female           0            -            -
# 396277  female          28            -            -
# 396278  female          43            -            -
# 396279  female          32            -            -
# 396280  female           0            -            -
# 396281  female          81  8.100583333    124.24025
# 396282  female           0            -            -
# 396283  female           0            -            -
# 396284  female           0            -            -
# 396285  female           0            -            -
# 396286  female          52            -            -
# 396287  female          40            -            -
#
# [460944 rows x 11 columns]

# %% [markdown]
# ### B. Merge
# Merging is the most common way to combine multiple data frames and has more flexibility than concat.

# %%
df3 = pd.DataFrame([['a','b','c'],['d','e','f'],['g','h','i']]\
                   ,columns=['col1','col2','col3'])
df4 = pd.DataFrame({'col2':['x','e','b','z'],'col4':[1,2,3,4],'col5':['i','f','e','h']})
display(df3)
display(df4)
# Out:
#   col1 col2 col3
# 0    a    b    c
# 1    d    e    f
# 2    g    h    i
#   col2  col4 col5
# 0    x     1    i
# 1    e     2    f
# 2    b     3    e
# 3    z     4    h

# %% [markdown]
# - Merging will use the **`on`** column as a key for the merge.  The code below identifies the column ‘col2’ from both data frames.
# - The argument **`how`** set to 'inner' makes the merge only keep rows occuring in both data frames.

# %%
pd.merge(df3, df4, how='inner', on ='col2')
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c     3    e
# 1    d    e    f     2    f

# %% [markdown]
# - The default value of the parameter `how` is 'inner'. The following code performs the same task as above.

# %%
pd.merge(df3, df4, on ='col2')
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c     3    e
# 1    d    e    f     2    f

# %% [markdown]
# - To keep every row in df1 then set the parameter `how` = 'left'.

# %%
pd.merge(df3, df4, how='left', on ='col2')
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c   3.0    e
# 1    d    e    f   2.0    f
# 2    g    h    i   NaN  NaN

# %% [markdown]
# - To keep all rows from both df1 and df2, set the parameter `how` = 'outer'.

# %%
pd.merge(df3, df4, how='outer', on ='col2')
# Out:
#   col1 col2 col3  col4 col5
# 0    a    b    c   3.0    e
# 1    d    e    f   2.0    f
# 2    g    h    i   NaN  NaN
# 3  NaN    x  NaN   1.0    i
# 4  NaN    z  NaN   4.0    h

# %% [markdown]
# - If the `on` column does not have the same name in the two data frames, use 'left_on' and 'right_on' to indicate how to perform the merge.
# - Note that columns with the same name, in the two data frames, will be named with an x or y character appended.

# %%
pd.merge(df3, df4, left_on='col2', right_on='col5')
# Out:
#   col1 col2_x col3 col2_y  col4 col5
# 0    d      e    f      b     3    e
# 1    g      h    i      z     4    h

# %% [markdown]
# ### Try it!

# %% [markdown]
# Let's try adding variables from `schools.csv` that are not present in the df_all_schools data we prepared.

# %%
# Add data from a different dataset
additional_data = pd.read_csv("schools.csv")
additional_data.head()
# Out:
#    Unnamed: 0  OBJECTID Region     Division      ID  \
# 0           0         1    NCR  Quezon City  319506
# 1           1         2    NCR   Pasay City  319602
# 2           2         3    NCR   Pasay City  319603
# 3           3         4    NCR   Pasay City  223002
# 4           4         5    NCR   Pasay City  223001
#
#                                               School   Municipali Legislativ  \
# 0  National Orthopedic Hospital School for Crippl...  QUEZON CITY        1st
# 1           Philippine National School for the Blind   PASAY CITY       Lone
# 2                     Philippine School for the Deaf   PASAY CITY       Lone
# 3                     Philippine School for the Deaf   PASAY CITY       Lone
# 4           Philippine National School for the Blind   PASAY CITY       Lone
#
#    Total_Enro  Total_Inst Color_Code Barangay             Province  \
# 0          85           8       Blue      NaN  NCR SECOND DISTRICT
# 1          27           9       Blue      NaN  NCR FOURTH DISTRICT
# 2         251          84       Blue      NaN  NCR FOURTH DISTRICT
# 3         260          84       Blue      NaN  NCR FOURTH DISTRICT
# 4          46           9       Blue      NaN  NCR FOURTH DISTRICT
#
#                    District              Type_of_Sc  Rooms_used  Rooms_unused
# 0         School District I  School with no Annexes         6.0           0.0
# 1  Pasay City West District  School with no Annexes         5.0           0.0
# 2  Pasay City West District  School with no Annexes        25.0           0.0
# 3  Pasay City West District  School with no Annexes        38.0           0.0
# 4  Pasay City West District  School with no Annexes         7.0           2.0

# %% [markdown]
# Which columns can we add?

# %%
data_to_add = additional_data[["ID", "Total_Enro", "Total_Inst", "Rooms_used", "Rooms_unused", "Type_of_Sc"]]

# %%
pd.merge(df_all_schools,data_to_add,left_on="school_id",right_on="ID",how="inner")
# Out:
#         school_id                 school_name  \
# 0          300002                Bacarra NCHS
# 1          300002                Bacarra NCHS
# 2          300002                Bacarra NCHS
# 3          300002                Bacarra NCHS
# 4          300002                Bacarra NCHS
# 5          300002                Bacarra NCHS
# 6          300002                Bacarra NCHS
# 7          300002                Bacarra NCHS
# 8          300003                  Bangui NHS
# 9          300003                  Bangui NHS
# 10         300003                  Bangui NHS
# 11         300003                  Bangui NHS
# 12         300003                  Bangui NHS
# 13         300003                  Bangui NHS
# 14         300003                  Bangui NHS
# 15         300003                  Bangui NHS
# 16         300004  Banna National High School
# 17         300004  Banna National High School
# 18         300004  Banna National High School
# 19         300004  Banna National High School
# 20         300004  Banna National High School
# 21         300004  Banna National High School
# 22         300004  Banna National High School
# 23         300004  Banna National High School
# 24         300005  Batac National High School
# 25         300005  Batac National High School
# 26         300005  Batac National High School
# 27         300005  Batac National High School
# 28         300005  Batac National High School
# 29         300005  Batac National High School
# ...           ...                         ...
# 159714     133445                    Tambo ES
# 159715     133445                    Tambo ES
# 159716     133445                    Tambo ES
# 159717     133445                    Tambo ES
# 159718     133445                    Tambo ES
# 159719     133445                    Tambo ES
# 159720     133451               Saguiaran CES
# 159721     133451               Saguiaran CES
# 159722     133451               Saguiaran CES
# 159723     133451               Saguiaran CES
# 159724     133451               Saguiaran CES
# 159725     133451               Saguiaran CES
# 159726     133451               Saguiaran CES
# 159727     133451               Saguiaran CES
# 159728     133451               Saguiaran CES
# 159729     133451               Saguiaran CES
# 159730     133451               Saguiaran CES
# 159731     133451               Saguiaran CES
# 159732     133470                    Pawak ES
# 159733     133470                    Pawak ES
# 159734     133470                    Pawak ES
# 159735     133470                    Pawak ES
# 159736     133470                    Pawak ES
# 159737     133470                    Pawak ES
# 159738     133470                    Pawak ES
# 159739     133470                    Pawak ES
# 159740     133470                    Pawak ES
# 159741     133470                    Pawak ES
# 159742     133470                    Pawak ES
# 159743     133470                    Pawak ES
#
#                                              region       province  \
# 0                          Region I - Ilocos Region   Ilocos Norte
# 1                          Region I - Ilocos Region   Ilocos Norte
# 2                          Region I - Ilocos Region   Ilocos Norte
# 3                          Region I - Ilocos Region   Ilocos Norte
# 4                          Region I - Ilocos Region   Ilocos Norte
# 5                          Region I - Ilocos Region   Ilocos Norte
# 6                          Region I - Ilocos Region   Ilocos Norte
# 7                          Region I - Ilocos Region   Ilocos Norte
# 8                          Region I - Ilocos Region   Ilocos Norte
# 9                          Region I - Ilocos Region   Ilocos Norte
# 10                         Region I - Ilocos Region   Ilocos Norte
# 11                         Region I - Ilocos Region   Ilocos Norte
# 12                         Region I - Ilocos Region   Ilocos Norte
# 13                         Region I - Ilocos Region   Ilocos Norte
# 14                         Region I - Ilocos Region   Ilocos Norte
# 15                         Region I - Ilocos Region   Ilocos Norte
# 16                         Region I - Ilocos Region   Ilocos Norte
# 17                         Region I - Ilocos Region   Ilocos Norte
# 18                         Region I - Ilocos Region   Ilocos Norte
# 19                         Region I - Ilocos Region   Ilocos Norte
# 20                         Region I - Ilocos Region   Ilocos Norte
# 21                         Region I - Ilocos Region   Ilocos Norte
# 22                         Region I - Ilocos Region   Ilocos Norte
# 23                         Region I - Ilocos Region   Ilocos Norte
# 24                         Region I - Ilocos Region   Ilocos Norte
# 25                         Region I - Ilocos Region   Ilocos Norte
# 26                         Region I - Ilocos Region   Ilocos Norte
# 27                         Region I - Ilocos Region   Ilocos Norte
# 28                         Region I - Ilocos Region   Ilocos Norte
# 29                         Region I - Ilocos Region   Ilocos Norte
# ...                                             ...            ...
# 159714  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159715  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159716  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159717  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159718  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159719  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159720  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159721  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159722  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159723  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159724  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159725  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159726  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159727  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159728  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159729  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159730  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159731  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159732  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159733  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159734  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159735  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159736  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159737  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159738  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159739  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159740  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159741  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159742  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
# 159743  ARMM - Autonomous Region in Muslim Mindanao  Lanao Del Sur
#
#             municipality           division   year_level  gender  enrollment  \
# 0                Bacarra       Ilocos Norte   first year    male         299
# 1                Bacarra       Ilocos Norte   first year  female         250
# 2                Bacarra       Ilocos Norte  second year    male         246
# 3                Bacarra       Ilocos Norte  second year  female         284
# 4                Bacarra       Ilocos Norte   third year    male         220
# 5                Bacarra       Ilocos Norte   third year  female         254
# 6                Bacarra       Ilocos Norte  fourth year    male         214
# 7                Bacarra       Ilocos Norte  fourth year  female         225
# 8                 Bangui       Ilocos Norte   first year    male          89
# 9                 Bangui       Ilocos Norte   first year  female          78
# 10                Bangui       Ilocos Norte  second year    male          85
# 159743  8.049722222  124.2658333  133470         259           9         6.0
#
#         Rooms_unused              Type_of_Sc
# 0                0.0  School with no Annexes
# 1                0.0  School with no Annexes
# 2                0.0  School with no Annexes
# 3                0.0  School with no Annexes
# 4                0.0  School with no Annexes
# 5                0.0  School with no Annexes
# 6                0.0  School with no Annexes
# 7                0.0  School with no Annexes
# 8                0.0           Mother school
# 9                0.0           Mother school
# 10               0.0           Mother school
# 11               0.0           Mother school
# 12               0.0           Mother school
# 13               0.0           Mother school
# 14               0.0           Mother school
# 15               0.0           Mother school
# 16               0.0  School with no Annexes
# 17               0.0  School with no Annexes
# 18               0.0  School with no Annexes
# 19               0.0  School with no Annexes
# 20               0.0  School with no Annexes
# 21               0.0  School with no Annexes
# 22               0.0  School with no Annexes
# 23               0.0  School with no Annexes
# 24               1.0           Mother school
# 25               1.0           Mother school
# 26               1.0           Mother school
# 27               1.0           Mother school
# 28               1.0           Mother school
# 29               1.0           Mother school
# ...              ...                     ...
# 159714           0.0  School with no Annexes
# 159715           0.0  School with no Annexes
# 159716           0.0  School with no Annexes
# 159717           0.0  School with no Annexes
# 159718           0.0  School with no Annexes
# 159719           0.0  School with no Annexes
# 159720           0.0  School with no Annexes
# 159721           0.0  School with no Annexes
# 159722           0.0  School with no Annexes
# 159723           0.0  School with no Annexes
# 159724           0.0  School with no Annexes
# 159725           0.0  School with no Annexes
# 159726           0.0  School with no Annexes
# 159727           0.0  School with no Annexes
# 159728           0.0  School with no Annexes
# 159729           0.0  School with no Annexes
# 159730           0.0  School with no Annexes
# 159731           0.0  School with no Annexes
# 159732           0.0  School with no Annexes
# 159733           0.0  School with no Annexes
# 159734           0.0  School with no Annexes
# 159735           0.0  School with no Annexes
# 159736           0.0  School with no Annexes
# 159737           0.0  School with no Annexes
# 159738           0.0  School with no Annexes
# 159739           0.0  School with no Annexes
# 159740           0.0  School with no Annexes
# 159741           0.0  School with no Annexes
# 159742           0.0  School with no Annexes
# 159743           0.0  School with no Annexes
#
# [159744 rows x 17 columns]

# %% [markdown]
# How should we combine them?

# %%
# Combine select columns from additional_data to the df_all_schools

#df_all =

# %%
df_all = pd.merge(df_all_schools,data_to_add,left_on="school_id",right_on="ID",how="inner")

# %%
df_all.to_csv("schools_combined.csv")

# %% [markdown]
# Let's check the shape of our new dataframe

# %%
df_all.shape
# Out:
# (159744, 17)

# %%
df_all.isna().sum()
# Out:
# school_id        0
# school_name      0
# region           0
# province         0
# municipality     0
# division         0
# year_level       0
# gender           0
# enrollment       0
# latitude         0
# longitude        0
# ID               0
# Total_Enro       0
# Total_Inst       0
# Rooms_used      12
# Rooms_unused    12
# Type_of_Sc       0
# dtype: int64

# %% [markdown]
# You may have noticed that there are lots of missing values in our new dataframe. One way to avoid missing values is to obtain only the schools that are present in both dataframes. Let's try doing that.

# %%
# Add data but obtain only common primary key
df_all_new = pd.merge(df_all_schools,data_to_add,on="school")
# Check shape

# %%
# Check data frame

# %% [markdown]
# ### Saving to csv

# %% [markdown]
# Now that we have our new clean dataframe, let's save it to a new file.

# %%
#df_inner.to_csv("schools_combined.csv")
