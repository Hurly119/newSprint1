# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
df_schools = pd.read_csv("Masterlist of Schools.csv", index_col="school.id")

df_location = pd.read_csv("Schools Location Data.csv", 
                          encoding = "latin-1", 
                          index_col="School ID",
                          usecols=["School ID", "Enrolment", "Latitude", "Longitude"])

df_rooms = pd.read_csv('Rooms data.csv', index_col="School ID")

df_teachers = pd.read_csv("Teachers data.csv", index_col="school.id")

df_elementary = pd.read_csv("Enrollment Master Data_2015_E.csv")[:-1].astype(int).set_index("School ID")

df_secondary = (pd.read_csv('Enrollment Master Data_2015_S.csv')[:-1]
                  .replace(",", "", regex=True)
                  .astype(int)
                  .replace("SPED NG Male", "SPED NG Male SS")
                  .replace("SPED NG Female", "SPED NG Female SS")
                  .set_index("School ID"))

df_mooe = (pd.read_csv('MOOE data.csv', index_col="school.id", usecols=["school.id", " school.mooe "])
             .replace(",", "", regex=True).astype(float))

# %%
df_mooe
# Out:
#             school.mooe
# school.id
# 305075         2182000.0
# 134966          227000.0
# 134967          144000.0
# 134968          339000.0
# 134969          178000.0
# ...                  ...
# 131231          180000.0
# 131233          248000.0
# 131236          242000.0
# 131237          841000.0
# 304624         2345000.0
#
# [44028 rows x 1 columns]

# %%
df_all = pd.concat([df_schools, df_location, df_rooms, df_teachers, df_elementary, df_secondary, df_mooe], axis=1)
df_all
# Out:
#                                               school.name school.region  \
# 100001                                 Apaleng-Libtong ES      Region I
# 100002                                        Bacarra CES      Region I
# 100003                                           Buyon ES      Region I
# 100004                                         Ganagan ES      Region I
# 100005                                         Macupit ES      Region I
# ...                                                   ...           ...
# 326101     Upper Katungal National High School-TNHS Annex    Region XII
# 326102            San Emmanuel National High School-Annex    Region XII
# 326501                         Sulon National High School          ARMM
# 356059  Ocana National High School (Kalangyawon Extens...    Region VII
# 900279             Quirino State University-Laboratory HS     Region II
#
#                           school.region.name school.province school.cityhall  \
# 100001                         Ilocos Region    ILOCOS NORTE    ILOCOS NORTE
# 100002                         Ilocos Region    ILOCOS NORTE    ILOCOS NORTE
# 100003                         Ilocos Region    ILOCOS NORTE    ILOCOS NORTE
# 100004                         Ilocos Region    ILOCOS NORTE    ILOCOS NORTE
# 100005                         Ilocos Region    ILOCOS NORTE    ILOCOS NORTE
# ...                                      ...             ...             ...
# 326101                          Soccsksargen  SULTAN KUDARAT  SULTAN KUDARAT
# 326102                          Soccsksargen  SULTAN KUDARAT  SULTAN KUDARAT
# 326501  Autonomous Region in Muslim Mindanao     MAGUINDANAO     MAGUINDANAO
# 356059                       Central Visayas            CEBU            CEBU
# 900279                        Cagayan Valley         QUIRINO         QUIRINO
#
#        school.division   school.citymuni school.district school.legdistrict  \
# 100001    Ilocos Norte           BACARRA       Bacarra I       1st District
# 100002    Ilocos Norte           BACARRA       Bacarra I       1st District
# 100003    Ilocos Norte           BACARRA       Bacarra I       1st District
# 100004    Ilocos Norte           BACARRA       Bacarra I       1st District
# 100005    Ilocos Norte           BACARRA       Bacarra I       1st District
# ...                ...               ...             ...                ...
# 326101   Tacurong City  CITY OF TACURONG  Tacurong South       1st District
# 326102   Tacurong City  CITY OF TACURONG   Tacurong East       1st District
# 326501  Maguindanao II    SULTAN MASTURA  Sultan Mastura       1st District
# 356059     Carcar City    CITY OF CARCAR       Carcar II       1st District
# 900279         Quirino            DIFFUN        Diffun I      Lone District
#
#                          school.type     school.abbrev  \
# 100001        School with no Annexes               NaN
# 100002        School with no Annexes               NaN
# 100003        School with no Annexes               NaN
# 100004        School with no Annexes               NaN
# 100005        School with no Annexes               NaN
# ...                              ...               ...
# 326101  Annex or Extension school(s)  UKNHS-TNHS Annex
# 326102  Annex or Extension school(s)       SENHS-Annex
# 326501        School with no Annexes               NaN
# 356059  Annex or Extension school(s)          ONHS-Ext
# 900279        School with no Annexes        QSU-Lab HS
#
#                         school.previousname  school.mother.id  \
# 100001                   Apaleng-Libtong PS          100001.0
# 100002                                    -          100002.0
# 100003                                    -          100003.0
# 100004                                  NaN          100004.0
# 100005                                    -          100005.0
# ...                                     ...               ...
# 326101  Tacurong NHS - Upper Katungal Annex          304624.0
# 326102                                  NaN          304622.0
# 326501                                  NaN          326501.0
# 356059                                 -n.a          303066.0
# 900279  Quirino State College-Laboratory HS          900279.0
#
#                                   school.address school.established  \
# 100001                                         -           1/1/1996
# 100002                                Santa Rita           1/1/1914
# 100003                                      NONE           1/1/1947
# 100004                                      NONE           1/1/1949
# 100005                                   Macupit           1/1/1913
# ...                                          ...                ...
# 326101                            Upper Katungal           1/1/2011
# 326102  Purok San Jose, San Pablo, Tacurong City           1/1/2012
# 326501                               Brgy. Sulon          1/26/1968
# 356059                         Kalangyawon, Napo           1/1/2009
# 900279                                   Purok 3           1/1/1975
#
#        school.classification school.classification2 school.curricularclass  \
# 100001            Elementary          DepED Managed    Kinder & Elementary
# 100002            Elementary          DepED Managed             Elementary
# 100003            Elementary          DepED Managed             Elementary
# 100004            Elementary          DepED Managed             Elementary
# 100005            Elementary          DepED Managed             Elementary
# ...                      ...                    ...                    ...
# 326101             Secondary          DepED Managed              Secondary
# 326102             Secondary          DepED Managed              Secondary
# 326501             Secondary          DepED Managed              Secondary
# 356059             Secondary          DepED Managed              Secondary
# 900279             Secondary            SUC Managed              Secondary
#
#                       school.organization  \
# 100001  Combined Monograde and Multigrade
# 100002                          Monograde
# 100003                          Monograde
# 100004                          Monograde
# 100005                          Monograde
# ...                                   ...
# 326101                          Monograde
# 326102                          Monograde
# 326501                          Monograde
# 356059                          Monograde
# 900279                          Monograde
#
#                             school.cityincome school.cityclass  \
# 100001    P 35 M or more but less than P 45 M              NaN
# 100002    P 35 M or more but less than P 45 M              NaN
# 100003    P 35 M or more but less than P 45 M              NaN
# 100004    P 35 M or more but less than P 45 M              NaN
# 100005    P 35 M or more but less than P 45 M              NaN
# ...                                       ...              ...
# 326101  P 160 M or more but less than P 240 M   Component City
# 326102  P 160 M or more but less than P 240 M   Component City
# 326501    P 15 M or more but less than P 25 M              NaN
# 356059                                    NaN   Component City
# 900279    P 45 M or more but less than P 55 M              NaN
#
#            school.urban  Enrolment   Latitude   Longitude  \
# 100001  Partially Urban       90.0  18.253666  120.606180
# 100002  Partially Urban      456.0  18.250964  120.608958
# 100003  Partially Urban      167.0  18.234599  120.616037
# 100004  Partially Urban      122.0  18.250014  120.587169
# 100005  Partially Urban       77.0  18.293994  120.641019
# ...                 ...        ...        ...         ...
# 326101  Partially Urban      262.0   6.649561  124.660667
# 326102  Partially Urban      191.0   6.697856  124.701979
# 326501  Partially Urban      185.0   0.000000    0.000000
# 356059  Partially Urban      136.0  10.067247  123.627106
# 900279  Partially Urban        NaN        NaN         NaN
#
#         rooms.standard.academic  rooms.standard.unused  \
# 100001                      2.0                    0.0
# 100002                     12.0                    0.0
# 100003                      6.0                    0.0
# 100004                      6.0                    0.0
# 100005                      6.0                    0.0
# ...                         ...                    ...
# 326101                      2.0                    0.0
# 326102                      2.0                    0.0
# 326501                      NaN                    NaN
# 356059                      3.0                    0.0
# 900279                      NaN                    NaN
#
#         rooms.nonstandard.academic  rooms.nonstandard.unused  \
# 100001                         0.0                       0.0
# 100002                         0.0                       0.0
# 100003                         0.0                       0.0
# 100004                         0.0                       0.0
# 100005                         0.0                       0.0
# ...                            ...                       ...
# 326101                         0.0                       0.0
# 326102                         0.0                       0.0
# 326501                         NaN                       NaN
# 356059                         0.0                       0.0
# 900279                         NaN                       NaN
#
#         teachers.instructor  teachers.mobile  teachers.regular  teachers.sped  \
# 100001                  0.0              0.0               2.0            0.0
# 100002                  0.0              6.0              11.0            0.0
# 100003                  0.0              1.0               6.0            0.0
# 100004                  0.0              1.0               6.0            0.0
# 100005                  0.0              1.0               6.0            0.0
# ...                     ...              ...               ...            ...
# 326101                  NaN              NaN               NaN            NaN
# 326102                  NaN              NaN               NaN            NaN
# 326501                  0.0              0.0               0.0            0.0
# 356059                  NaN              NaN               NaN            NaN
# 900279                  0.0              0.0               0.0            0.0
#
#         Kinder Male  Kinder Female  Grade 1 Male  Grade 1 Female  \
# 100001          9.0            7.0           7.0             2.0
# 100002         41.0           25.0          38.0            33.0
# 100003          8.0           10.0          13.0            15.0
# 100004          8.0            4.0           9.0            12.0
# 100005          4.0            2.0           5.0             7.0
# ...             ...            ...           ...             ...
# 326101          NaN            NaN           NaN             NaN
# 326102          NaN            NaN           NaN             NaN
# 326501          NaN            NaN           NaN             NaN
# 356059          NaN            NaN           NaN             NaN
# 900279          NaN            NaN           NaN             NaN
#
#         Grade 2 Male  Grade 2 Female  Grade 3 Male  Grade 3 Female  \
# 100001           7.0             7.0           9.0             5.0
# 100002          41.0            40.0          28.0            31.0
# 100003          13.0            13.0          16.0            16.0
# 100004          12.0            10.0          10.0             5.0
# 100005           4.0             6.0           3.0             8.0
# ...              ...             ...           ...             ...
# 326101           NaN             NaN           NaN             NaN
# 326102           NaN             NaN           NaN             NaN
# 326501           NaN             NaN           NaN             NaN
# 356059           NaN             NaN           NaN             NaN
# 900279           NaN             NaN           NaN             NaN
#
#         Grade 4 Male  Grade 4 Female  Grade 5 Male  Grade 5 Female  \
# 100001           7.0             5.0           3.0             2.0
# 100002          38.0            30.0          26.0            31.0
# 100003          14.0            11.0           9.0            12.0
# 100004          14.0            11.0           5.0             7.0
# 100005          11.0             5.0           7.0             4.0
# ...              ...             ...           ...             ...
# 326101           NaN             NaN           NaN             NaN
# 326102           NaN             NaN           NaN             NaN
# 326501           NaN             NaN           NaN             NaN
# 356059           NaN             NaN           NaN             NaN
# 900279           NaN             NaN           NaN             NaN
#
#         Grade 6 Male  Grade 6 Female  SPED NG Male  SPED NG Female  \
# 100001          14.0             6.0           0.0             0.0
# 100002          22.0            32.0           0.0             0.0
# 100003          12.0             5.0           0.0             0.0
# 100004          10.0             5.0           0.0             0.0
# 100005           3.0             8.0           0.0             0.0
# ...              ...             ...           ...             ...
# 326101           NaN             NaN           NaN             NaN
# 326102           NaN             NaN           NaN             NaN
# 326501           NaN             NaN           NaN             NaN
# 356059           NaN             NaN           NaN             NaN
# 900279           NaN             NaN           NaN             NaN
#
#         Grade 7 Male  Grade 7 Female  Grade 8 Male  Grade 8 Female  \
# 100001           NaN             NaN           NaN             NaN
# 100002           NaN             NaN           NaN             NaN
# 100003           NaN             NaN           NaN             NaN
# 100004           NaN             NaN           NaN             NaN
# 100005           NaN             NaN           NaN             NaN
# ...              ...             ...           ...             ...
# 326101          48.0            37.0          33.0            31.0
# 326102          34.0            42.0          23.0            28.0
# 326501          29.0            53.0          32.0            48.0
# 356059          22.0            16.0          20.0            18.0
# 900279           NaN             NaN           NaN             NaN
#
#         Grade 9 Male  Grade 9 Female  Grade 10 Male  Grade 10 Female  \
# 100001           NaN             NaN            NaN              NaN
# 100002           NaN             NaN            NaN              NaN
# 100003           NaN             NaN            NaN              NaN
# 100004           NaN             NaN            NaN              NaN
# 100005           NaN             NaN            NaN              NaN
# ...              ...             ...            ...              ...
# 326101          24.0            27.0           37.0             25.0
# 326102          38.0            26.0            0.0              0.0
# 326501          15.0             8.0            0.0              0.0
# 356059          10.0            21.0           11.0             18.0
# 900279           NaN             NaN            NaN              NaN
#
#         Grade 11 Male  Grade 11 Female  Grade 12 Male  Grade 12 Female  \
# 100001            NaN              NaN            NaN              NaN
# 100002            NaN              NaN            NaN              NaN
# 100003            NaN              NaN            NaN              NaN
# 100004            NaN              NaN            NaN              NaN
# 100005            NaN              NaN            NaN              NaN
# ...               ...              ...            ...              ...
# 326101            0.0              0.0            0.0              0.0
# 326102            0.0              0.0            0.0              0.0
# 326501            0.0              0.0            0.0              0.0
# 356059            0.0              0.0            0.0              0.0
# 900279            NaN              NaN            NaN              NaN
#
#         SPED NG Male  SPED NG Female   school.mooe
# 100001           NaN             NaN        84000.0
# 100002           NaN             NaN       268000.0
# 100003           NaN             NaN       135000.0
# 100004           NaN             NaN       116000.0
# 100005           NaN             NaN       115000.0
# ...              ...             ...            ...
# 326101           0.0             0.0       174000.0
# 326102           0.0             0.0       144000.0
# 326501           0.0             0.0            NaN
# 356059           0.0             0.0       177000.0
# 900279           NaN             NaN            NaN
#
# [46751 rows x 64 columns]

# %%
df_all.shape
# Out:
# (46751, 64)

# %%
df_all.isna().sum()
# Out:
# school.name                     148
# school.region                   148
# school.region.name              148
# school.province                 148
# school.cityhall                 149
# school.division                 148
# school.citymuni                 148
# school.district                 148
# school.legdistrict              148
# school.type                     148
# school.abbrev                 28584
# school.previousname            4530
# school.mother.id                155
# school.address                 2130
# school.established              157
# school.classification           148
# school.classification2          148
# school.curricularclass          148
# school.organization             148
# school.cityincome              1124
# school.cityclass              38538
# school.urban                    151
# Enrolment                       127
# Latitude                        130
# Longitude                       130
# rooms.standard.academic         339
# rooms.standard.unused           339
# rooms.nonstandard.academic      343
# rooms.nonstandard.unused        343
# teachers.instructor            1711
# teachers.mobile                1711
# teachers.regular               1711
# teachers.sped                  1711
# Kinder Male                    8103
# Kinder Female                  8103
# Grade 1 Male                   8103
# Grade 1 Female                 8103
# Grade 2 Male                   8103
# Grade 2 Female                 8103
# Grade 3 Male                   8103
# Grade 3 Female                 8103
# Grade 4 Male                   8103
# Grade 4 Female                 8103
# Grade 5 Male                   8103
# Grade 5 Female                 8103
# Grade 6 Male                   8103
# Grade 6 Female                 8103
# SPED NG Male                   8103
# SPED NG Female                 8103
# Grade 7 Male                  38775
# Grade 7 Female                38775
# Grade 8 Male                  38775
# Grade 8 Female                38775
# Grade 9 Male                  38775
# Grade 9 Female                38775
# Grade 10 Male                 38775
# Grade 10 Female               38775
# Grade 11 Male                 38775
# Grade 11 Female               38775
# Grade 12 Male                 38775
# Grade 12 Female               38775
# SPED NG Male                  38775
# SPED NG Female                38775
#  school.mooe                   2723
# dtype: int64

# %%
df_all[df_all.index.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [school.name, school.region, school.region.name, school.province, school.cityhall, school.division, school.citymuni, school.district, school.legdistrict, school.type, school.abbrev, school.previousname, school.mother.id, school.address, school.established, school.classification, school.classification2, school.curricularclass, school.organization, school.cityincome, school.cityclass, school.urban, Enrolment, Latitude, Longitude, rooms.standard.academic, rooms.standard.unused, rooms.nonstandard.academic, rooms.nonstandard.unused, teachers.instructor, teachers.mobile, teachers.regular, teachers.sped, Kinder Male, Kinder Female, Grade 1 Male, Grade 1 Female, Grade 2 Male, Grade 2 Female, Grade 3 Male, Grade 3 Female, Grade 4 Male, Grade 4 Female, Grade 5 Male, Grade 5 Female, Grade 6 Male, Grade 6 Female, SPED NG Male, SPED NG Female, Grade 7 Male, Grade 7 Female, Grade 8 Male, Grade 8 Female, Grade 9 Male, Grade 9 Female, Grade 10 Male, Grade 10 Female, Grade 11 Male, Grade 11 Female, Grade 12 Male, Grade 12 Female, SPED NG Male, SPED NG Female,  school.mooe ]
# Index: []

# %%
df_all.columns
# Out:
# Index(['school.name', 'school.region', 'school.region.name', 'school.province',
#        'school.cityhall', 'school.division', 'school.citymuni',
#        'school.district', 'school.legdistrict', 'school.type', 'school.abbrev',
#        'school.previousname', 'school.mother.id', 'school.address',
#        'school.established', 'school.classification', 'school.classification2',
#        'school.curricularclass', 'school.organization', 'school.cityincome',
#        'school.cityclass', 'school.urban', 'Enrolment', 'Latitude',
#        'Longitude', 'rooms.standard.academic', 'rooms.standard.unused',
#        'rooms.nonstandard.academic', 'rooms.nonstandard.unused',
#        'teachers.instructor', 'teachers.mobile', 'teachers.regular',
#        'teachers.sped', 'Kinder Male', 'Kinder Female', 'Grade 1 Male',
#        'Grade 1 Female', 'Grade 2 Male', 'Grade 2 Female', 'Grade 3 Male',
#        'Grade 3 Female', 'Grade 4 Male', 'Grade 4 Female', 'Grade 5 Male',
#        'Grade 5 Female', 'Grade 6 Male', 'Grade 6 Female', 'SPED NG Male',
#        'SPED NG Female', 'Grade 7 Male', 'Grade 7 Female', 'Grade 8 Male',
#        'Grade 8 Female', 'Grade 9 Male', 'Grade 9 Female', 'Grade 10 Male',
#        'Grade 10 Female', 'Grade 11 Male', 'Grade 11 Female', 'Grade 12 Male',
#        'Grade 12 Female', 'SPED NG Male', 'SPED NG Female', ' school.mooe '],
#       dtype='object')

# %%
df_numeric = df_all[['rooms.standard.academic', 'rooms.standard.unused',
       'rooms.nonstandard.academic', 'rooms.nonstandard.unused',
       'teachers.instructor', 'teachers.mobile', 'teachers.regular',
       'teachers.sped','Enrolment', ' school.mooe ', 'school.classification']]
df_numeric
# Out:
#         rooms.standard.academic  rooms.standard.unused  \
# 100001                      2.0                    0.0
# 100002                     12.0                    0.0
# 100003                      6.0                    0.0
# 100004                      6.0                    0.0
# 100005                      6.0                    0.0
# ...                         ...                    ...
# 326101                      2.0                    0.0
# 326102                      2.0                    0.0
# 326501                      NaN                    NaN
# 356059                      3.0                    0.0
# 900279                      NaN                    NaN
#
#         rooms.nonstandard.academic  rooms.nonstandard.unused  \
# 100001                         0.0                       0.0
# 100002                         0.0                       0.0
# 100003                         0.0                       0.0
# 100004                         0.0                       0.0
# 100005                         0.0                       0.0
# ...                            ...                       ...
# 326101                         0.0                       0.0
# 326102                         0.0                       0.0
# 326501                         NaN                       NaN
# 356059                         0.0                       0.0
# 900279                         NaN                       NaN
#
#         teachers.instructor  teachers.mobile  teachers.regular  teachers.sped  \
# 100001                  0.0              0.0               2.0            0.0
# 100002                  0.0              6.0              11.0            0.0
# 100003                  0.0              1.0               6.0            0.0
# 100004                  0.0              1.0               6.0            0.0
# 100005                  0.0              1.0               6.0            0.0
# ...                     ...              ...               ...            ...
# 326101                  NaN              NaN               NaN            NaN
# 326102                  NaN              NaN               NaN            NaN
# 326501                  0.0              0.0               0.0            0.0
# 356059                  NaN              NaN               NaN            NaN
# 900279                  0.0              0.0               0.0            0.0
#
#         Enrolment   school.mooe  school.classification
# 100001       90.0        84000.0            Elementary
# 100002      456.0       268000.0            Elementary
# 100003      167.0       135000.0            Elementary
# 100004      122.0       116000.0            Elementary
# 100005       77.0       115000.0            Elementary
# ...           ...            ...                   ...
# 326101      262.0       174000.0             Secondary
# 326102      191.0       144000.0             Secondary
# 326501      185.0            NaN             Secondary
# 356059      136.0       177000.0             Secondary
# 900279        NaN            NaN             Secondary
#
# [46751 rows x 11 columns]

# %%
df_numeric["rooms_total"] = (df_numeric['rooms.standard.academic'] + 
                             df_numeric['rooms.standard.unused'] + 
                             df_numeric['rooms.nonstandard.academic'] + 
                             df_numeric['rooms.nonstandard.unused'])

df_numeric["teachers_total"] = (df_numeric['teachers.instructor'] + 
                             df_numeric['teachers.mobile'] + 
                             df_numeric['teachers.regular'] + 
                             df_numeric['teachers.sped'])
df_final = df_numeric.iloc[:, 8:]
df_final
# Out:
# <ipython-input-10-765191b1f89f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numeric["rooms_total"] = (df_numeric['rooms.standard.academic'] +
# <ipython-input-10-765191b1f89f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numeric["teachers_total"] = (df_numeric['teachers.instructor'] +
#         Enrolment   school.mooe  school.classification  rooms_total  \
# 100001       90.0        84000.0            Elementary          2.0
# 100002      456.0       268000.0            Elementary         12.0
# 100003      167.0       135000.0            Elementary          6.0
# 100004      122.0       116000.0            Elementary          6.0
# 100005       77.0       115000.0            Elementary          6.0
# ...           ...            ...                   ...          ...
# 326101      262.0       174000.0             Secondary          2.0
# 326102      191.0       144000.0             Secondary          2.0
# 326501      185.0            NaN             Secondary          NaN
# 356059      136.0       177000.0             Secondary          3.0
# 900279        NaN            NaN             Secondary          NaN
#
#         teachers_total
# 100001             2.0
# 100002            17.0
# 100003             7.0
# 100004             7.0
# 100005             7.0
# ...                ...
# 326101             NaN
# 326102             NaN
# 326501             0.0
# 356059             NaN
# 900279             0.0
#
# [46751 rows x 5 columns]

# %%
df_final.isna().sum()
# Out:
# Enrolment                 127
#  school.mooe             2723
# school.classification     148
# rooms_total               343
# teachers_total           1711
# dtype: int64

# %%
df_final_clean = df_final.dropna()
df_final_clean.shape
# Out:
# (42342, 5)

# %%
index_name = (df_final_clean[(df_final_clean["Enrolment"]==0.0) | 
                             (df_final_clean["teachers_total"]==0.0) |
                             (df_final_clean["rooms_total"]==0.0)].index)
index_name
# Out:
# Int64Index([100464, 100761, 102907, 104110, 104622, 104895, 107211, 107212,
#             107305, 107318,
#             ...
#             325301, 325302, 325303, 325304, 325305, 325307, 325308, 325502,
#             325901, 325902],
#            dtype='int64', length=627)

# %%
df_final_clean = df_final_clean.drop(index_name)
df_final_clean.shape[0]
# Out:
# 41715

# %%
dropped_rows = df_final.shape[0] - df_final_clean.shape[0]
dropped_rows
# Out:
# 5036

# %%
dropped_rows/df_final.shape[0]*100
# Out:
# 10.771962097067442

# %%
df_ratio_ss = df_final_clean[df_final_clean["school.classification"]=='Secondary'].drop(columns=["school.classification"])

# %%
melted = df_ratio_ss.melt()

sns.boxplot(melted.variable, melted.value)
# Out:
# C:\Users\Optiplex\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %%
# Insert code here
# Removing (statistical) outliers for Amount
Q1 = df_ratio_ss[' school.mooe '].quantile(0.05)
Q3 = df_ratio_ss[' school.mooe '].quantile(0.95)
IQR = Q3 - Q1
df_ratio_ss = (df_ratio_ss[(df_ratio_ss[' school.mooe '] >= Q1 - 1.5*IQR) & 
                           (df_ratio_ss[' school.mooe '] <= Q3 + 1.5*IQR)])

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection='3d')

teacher = df_ratio_ss.teachers_total
room = df_ratio_ss.rooms_total
budget = df_ratio_ss[' school.mooe ']
ax.scatter(teacher, room, budget, s=5)

ax.set_xlabel('Teacher')
ax.set_ylabel('Room')
ax.set_zlabel('Budget')

plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled_ss = scaler.fit_transform(df_ratio_ss)

# %%
print(df_scaled_ss.min())
print(df_scaled_ss.max())
# Out:
# -0.9573687257244511
# 9.856742101069873

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=4)
model.fit(df_scaled_ss)
cluster_labels = model.predict(df_scaled_ss)

# %%
from sklearn.cluster import KMeans

ssd = []
range_n_clusters = list(np.arange(1,16))

for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters)
    kmeans.fit(df_scaled_ss)
    
    ssd.append(kmeans.inertia_)
    
# plot the SSDs for each n_clusters
plt.plot(ssd)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df_scaled_ss)
cluster_labels = kmeans.predict(df_scaled_ss)   

df_ratio_ss['Cluster_Labels'] = cluster_labels
df_ratio_ss['Cluster_Labels'].value_counts()
# Out:
# 0    4517
# 2    1055
# 1     267
# Name: Cluster_Labels, dtype: int64

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples
range_n_clusters = list(np.arange(2,9))

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(df_scaled_ss)
    
    cluster_labels = kmeans.predict(df_scaled_ss)
    
    # silhouette score
    silhouette_avg = silhouette_score(df_scaled_ss, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.7492345436288593
# For n_clusters=3, the silhouette score is 0.6406903596361787
# For n_clusters=4, the silhouette score is 0.5699479037036321
# For n_clusters=5, the silhouette score is 0.5258581149043722
# For n_clusters=6, the silhouette score is 0.4491818387083663
# For n_clusters=7, the silhouette score is 0.44847285169226564
# For n_clusters=8, the silhouette score is 0.39058119483150733

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
mergings = linkage(df_scaled_ss, method="single", metric='euclidean')

dendrogram(mergings, p=10, truncate_mode="level", leaf_rotation=90)
plt.show()

# %%
mergings = linkage(df_scaled_ss, method="complete", metric='euclidean')
dendrogram(mergings, p=10, truncate_mode="level")
plt.show()

# %%
mergings = linkage(df_scaled_ss, method="average", metric='euclidean')
dendrogram(mergings, p=10, truncate_mode="level")
plt.show()

# %%
cluster_labels = cut_tree(mergings, n_clusters=3).reshape(-1, )

# %%
df_ratio_ss['Cluster_Labels'] = cluster_labels

# %%
df_ratio_ss['Cluster_Labels'].value_counts()

# %%
df_ratio_ss[df_ratio_ss['Cluster_Labels']==0]

# %%
df_ratio_ss[df_ratio_ss['Cluster_Labels']==1]

# %%
df_ratio_ss[df_ratio_ss['Cluster_Labels']==2]

# %% [markdown]
# - Does it makes sense to use the raw numbers as features? What can be an alternative to the raw numbers?
# - Are there outliers in the other features as well?
# - Try exploring different number of clusters. How many clusters can you characterize?
# - Try playing with different hierarchical methods. Which gives the best result?

# %%
import seaborn as sns
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,8))

sns.boxplot(x="Cluster_Labels", y="Enrolment", data=df_ratio_ss, ax=axes[0,0])
axes[0,0].set_title("Enrolment", fontsize=16)

sns.boxplot(x=df_ratio_ss.Cluster_Labels, y=df_ratio_ss[" school.mooe "], ax=axes[0,1])
axes[0,1].set_title("MOOE", fontsize=16)

sns.boxplot(x=df_ratio_ss.Cluster_Labels, y=df_ratio_ss.rooms_total, ax=axes[1,0])
axes[1,0].set_title("Rooms", fontsize=16)

sns.boxplot(x=df_ratio_ss.Cluster_Labels, y=df_ratio_ss.teachers_total, ax=axes[1,1])
axes[1,1].set_title("Teachers", fontsize=16)

plt.tight_layout()
plt.show();

# %% [markdown]
# #### T-SNE
# - t-SNE = “t-distributed stochastic neighbor embedding”
# - Maps samples to 2D space (or 3D)
# - Map approximately preserves nearness of samples
# - Great for inspecting datasets

# %%
# t-SNE visualization of grain dataset

# Import TSNE
from sklearn.manifold import TSNE

variety_numbers = list(df_ratio_ss.iloc[:,-1])

# Create a TSNE instance: model
model = TSNE(learning_rate=300, perplexity=30)

# Apply fit_transform to samples: tsne_features
tsne_features = model.fit_transform(df_scaled_ss)

# Select the 0th feature: xs
xs = tsne_features[:,0]

# Select the 1st feature: ys
ys = tsne_features[:,1]

# Scatter plot, coloring by variety_numbers
plt.scatter(xs,ys,c=variety_numbers)
plt.show()

# %% [markdown]
# #### Radar Chart

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_minmax = scaler.fit_transform(df_ratio_ss)

df_minmax = pd.DataFrame(df_minmax, index=df_ratio_ss.index, columns=df_ratio_ss.columns)

df_minmax['Cluster_Labels'] = cluster_labels

df_clusters = df_minmax.set_index("Cluster_Labels")
df_clusters = df_clusters.groupby("Cluster_Labels").mean().reset_index()
df_clusters

# %%
from math import pi
def make_spider( row, title, color):
 
    # number of variable
    categories=list(df_clusters)[1:]
    N = len(categories)
 
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
 
    # Initialise the spider plot
    ax = plt.subplot(3,3,row+1, polar=True )
 
    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 3.5)
    ax.set_theta_direction(-1)
    
    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)
 
    # Draw ylabels
    ax.set_rlabel_position(0)
#     plt.yticks([-2, -1, 0, 1, 2], [-2,-1, 0, 1, 2], color="grey", size=7) #for sscaled
#     plt.ylim(-2.5,2.5)
    plt.yticks([-0.25, 0, 0.25, 0.5, 0.75, 1], [-0.25, 0, 0.25, 0.5,0.75, 1], color="grey", size=7) #formmscaled
    plt.ylim(-0.25,1)

    # Ind1
    values=df_clusters.loc[row].drop('Cluster_Labels').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)
 
    # Add a title
    plt.title(title, size=14, color=color, y=1.1)

# %%
my_dpi=100
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
plt.subplots_adjust(hspace=0.5)

# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df_clusters.index))

for row in range(0, len(df_clusters.index)):
    make_spider(row=row, 
                title='Segment '+(df_clusters['Cluster_Labels'][row]).astype(str), 
                color=my_palette(row))
