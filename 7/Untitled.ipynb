# %%
import pandas as pd

# %%
df = pd.read_csv("Day7_Exercise.csv")

# %%
df = df[~df.isna().any(axis=1)]
df
# Out:
#     Student# How reliable is your internet connection? [Python]  \
# 0        1.0                            Often reliable        1
# 1        2.0                            Often reliable        2
# 2        3.0                            Often reliable        3
# 3        4.0                           Always reliable        3
# 4        5.0                            Often reliable        3
# 5        6.0                            Often reliable        1
# 6        7.0                         Somewhat reliable        1
# 7        8.0                         Somewhat reliable        3
# 8        9.0                            Often reliable        2
# 9       10.0                            Often reliable        1
# 10      11.0                         Somewhat reliable        1
# 11      12.0                            Often reliable        3
# 12      13.0                           Always reliable        3
# 13      14.0                            Often reliable        3
# ...
